# %% [markdown]
# # Getting started with TinyTimeMixer (TTM)
#
# This notebooke demonstrates the usage of a pre-trained `TinyTimeMixer` model for several multivariate time series forecasting tasks. For details related to model architecture, refer to the [TTM paper](https://arxiv.org/pdf/2401.03955.pdf).
#
# In this example, we will use a pre-trained TTM-512-96 model. That means the TTM model can take an input of 512 time points (`context_length`), and can forecast upto 96 time points (`forecast_length`) in the future. We will use the pre-trained TTM in two settings:
# 1. **Zero-shot**: The pre-trained TTM will be directly used to evaluate on the `test` split of the target data. Note that the TTM was NOT pre-trained on the target data.
# 2. **Few-shot**: The pre-trained TTM will be quickly fine-tuned on only 5% of the `train` split of the target data, and subsequently, evaluated on the `test` part of the target data.
#
# Note: Alternatively, this notebook can be modified to try the TTM-1024-96 model.
#
# Pre-trained TTM models will be fetched from the [Hugging Face TTM Model Repository](https://huggingface.co/ibm-granite/granite-timeseries-ttm-v1).

# %% [markdown]
# ## Installation

# %%
# Clone the ibm/tsfm
! git clone https://github.com/IBM-granite/granite-tsfm.git
# Out:
# fatal: destination path 'tsfm' already exists and is not an empty directory.

# %%
# Change directory. Move inside the tsfm repo.
# %cd tsfm
# Out:
# /dccstor/dnn_forecasting/FM/tsfm_hf_refactor/public_repo/public/my_fork/tsfm/notebooks/tutorial/tsfm

# %%
# Do ls
! ls
# Out:
# build	 Makefile	 README.md  tsfmhfdemos		  ttm_finetuned_models
# hacking  notebooks	 scripts    tsfm_public		  wiki.md
# LICENSE  pyproject.toml  tests	    tsfm_public.egg-info

# %%
# Install the tsfm library
! pip install ".[notebooks]"
# Out:
# Processing /dccstor/dnn_forecasting/FM/tsfm_hf_refactor/public_repo/public/my_fork/tsfm/notebooks/tutorial/tsfm
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas>=2.2.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tsfm_public==0.2.0) (2.2.2)
# Requirement already satisfied: transformers[torch]>=4.36.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tsfm_public==0.2.0) (4.37.2)
# Requirement already satisfied: datasets in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tsfm_public==0.2.0) (2.14.4)
# Requirement already satisfied: scikit-learn in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tsfm_public==0.2.0) (1.2.2)
# Requirement already satisfied: deprecated in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tsfm_public==0.2.0) (1.2.14)
# Requirement already satisfied: kaleido in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tsfm_public==0.2.0) (0.2.1)
# Requirement already satisfied: jupyter in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tsfm_public==0.2.0) (1.0.0)
# Requirement already satisfied: plotly in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tsfm_public==0.2.0) (5.16.1)
# Requirement already satisfied: matplotlib in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tsfm_public==0.2.0) (3.8.3)
# Requirement already satisfied: tensorboard in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tsfm_public==0.2.0) (2.13.0)
# Requirement already satisfied: ipywidgets in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tsfm_public==0.2.0) (8.1.2)
# Requirement already satisfied: numpy>=1.22.4 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from pandas>=2.2.0->tsfm_public==0.2.0) (1.23.5)
# Requirement already satisfied: tzdata>=2022.7 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from pandas>=2.2.0->tsfm_public==0.2.0) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from pandas>=2.2.0->tsfm_public==0.2.0) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from pandas>=2.2.0->tsfm_public==0.2.0) (2.8.2)
# Requirement already satisfied: safetensors>=0.4.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from transformers[torch]>=4.36.1->tsfm_public==0.2.0) (0.4.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from transformers[torch]>=4.36.1->tsfm_public==0.2.0) (0.20.2)
# Requirement already satisfied: requests in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from transformers[torch]>=4.36.1->tsfm_public==0.2.0) (2.31.0)
# Requirement already satisfied: regex!=2019.12.17 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from transformers[torch]>=4.36.1->tsfm_public==0.2.0) (2023.8.8)
# Requirement already satisfied: tqdm>=4.27 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from transformers[torch]>=4.36.1->tsfm_public==0.2.0) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from transformers[torch]>=4.36.1->tsfm_public==0.2.0) (6.0)
# Requirement already satisfied: packaging>=20.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from transformers[torch]>=4.36.1->tsfm_public==0.2.0) (23.2)
# Requirement already satisfied: filelock in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from transformers[torch]>=4.36.1->tsfm_public==0.2.0) (3.8.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from transformers[torch]>=4.36.1->tsfm_public==0.2.0) (0.15.0)
# Requirement already satisfied: accelerate>=0.21.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from transformers[torch]>=4.36.1->tsfm_public==0.2.0) (0.22.0)
# Requirement already satisfied: torch!=1.12.0,>=1.11 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from transformers[torch]>=4.36.1->tsfm_public==0.2.0) (2.3.0)
# Requirement already satisfied: multiprocess in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from datasets->tsfm_public==0.2.0) (0.70.12.2)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from datasets->tsfm_public==0.2.0) (0.3.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from datasets->tsfm_public==0.2.0) (12.0.1)
# Requirement already satisfied: aiohttp in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from datasets->tsfm_public==0.2.0) (3.8.4)
# Requirement already satisfied: xxhash in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from datasets->tsfm_public==0.2.0) (3.3.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from datasets->tsfm_public==0.2.0) (2023.6.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from deprecated->tsfm_public==0.2.0) (1.15.0)
# Requirement already satisfied: ipython>=6.1.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipywidgets->tsfm_public==0.2.0) (8.14.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipywidgets->tsfm_public==0.2.0) (3.0.10)
# Requirement already satisfied: traitlets>=4.3.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipywidgets->tsfm_public==0.2.0) (5.9.0)
# Requirement already satisfied: comm>=0.1.3 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipywidgets->tsfm_public==0.2.0) (0.1.4)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipywidgets->tsfm_public==0.2.0) (4.0.10)
# Requirement already satisfied: nbconvert in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter->tsfm_public==0.2.0) (7.7.4)
# Requirement already satisfied: jupyter-console in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter->tsfm_public==0.2.0) (6.6.3)
# Requirement already satisfied: ipykernel in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter->tsfm_public==0.2.0) (6.25.1)
# Requirement already satisfied: notebook in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter->tsfm_public==0.2.0) (7.1.1)
# Requirement already satisfied: qtconsole in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter->tsfm_public==0.2.0) (5.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from matplotlib->tsfm_public==0.2.0) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.3.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from matplotlib->tsfm_public==0.2.0) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from matplotlib->tsfm_public==0.2.0) (4.38.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from matplotlib->tsfm_public==0.2.0) (6.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from matplotlib->tsfm_public==0.2.0) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from matplotlib->tsfm_public==0.2.0) (0.11.0)
# Requirement already satisfied: pillow>=8 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from matplotlib->tsfm_public==0.2.0) (9.3.0)
# Requirement already satisfied: tenacity>=6.2.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from plotly->tsfm_public==0.2.0) (8.2.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from scikit-learn->tsfm_public==0.2.0) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from scikit-learn->tsfm_public==0.2.0) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from scikit-learn->tsfm_public==0.2.0) (1.12.0)
# Requirement already satisfied: protobuf>=3.19.6 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tensorboard->tsfm_public==0.2.0) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tensorboard->tsfm_public==0.2.0) (65.5.0)
# Requirement already satisfied: grpcio>=1.48.2 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tensorboard->tsfm_public==0.2.0) (1.58.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tensorboard->tsfm_public==0.2.0) (2.2.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tensorboard->tsfm_public==0.2.0) (2.15.0)
# Requirement already satisfied: markdown>=2.6.8 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tensorboard->tsfm_public==0.2.0) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tensorboard->tsfm_public==0.2.0) (0.7.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tensorboard->tsfm_public==0.2.0) (1.0.0)
# Requirement already satisfied: absl-py>=0.4 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tensorboard->tsfm_public==0.2.0) (1.3.0)
# Requirement already satisfied: wheel>=0.26 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from tensorboard->tsfm_public==0.2.0) (0.37.1)
# Requirement already satisfied: psutil in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from accelerate>=0.21.0->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (5.9.5)
# Requirement already satisfied: multidict<7.0,>=4.5 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from aiohttp->datasets->tsfm_public==0.2.0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from aiohttp->datasets->tsfm_public==0.2.0) (1.9.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from aiohttp->datasets->tsfm_public==0.2.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from aiohttp->datasets->tsfm_public==0.2.0) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from aiohttp->datasets->tsfm_public==0.2.0) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from aiohttp->datasets->tsfm_public==0.2.0) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from aiohttp->datasets->tsfm_public==0.2.0) (23.1.0)
# Requirement already satisfied: six>=1.9.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->tsfm_public==0.2.0) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->tsfm_public==0.2.0) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->tsfm_public==0.2.0) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->tsfm_public==0.2.0) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->tsfm_public==0.2.0) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (4.11.0)
# Requirement already satisfied: zipp>=3.1.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->tsfm_public==0.2.0) (3.11.0)
# Requirement already satisfied: decorator in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.0) (0.19.0)
# Requirement already satisfied: pygments>=2.4.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.0) (2.16.1)
# Requirement already satisfied: matplotlib-inline in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.0) (0.1.6)
# Requirement already satisfied: backcall in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.0) (0.2.0)
# Requirement already satisfied: stack-data in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.0) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.0) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.0) (3.0.39)
# Requirement already satisfied: pickleshare in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public==0.2.0) (0.7.5)
# Requirement already satisfied: importlib-metadata>=4.4 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard->tsfm_public==0.2.0) (6.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from requests->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (2022.9.24)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from requests->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (1.26.16)
# Requirement already satisfied: idna<4,>=2.5 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from requests->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (3.4)
# Requirement already satisfied: jinja2 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (3.1.2)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (11.0.2.54)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (2.3.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (12.1.3.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (12.1.105)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (12.1.0.106)
# Requirement already satisfied: networkx in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (3.1)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (8.9.2.26)
# Requirement already satisfied: sympy in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (1.11.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (11.4.5.107)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (10.3.2.106)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard->tsfm_public==0.2.0) (2.1.1)
# Requirement already satisfied: tornado>=6.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipykernel->jupyter->tsfm_public==0.2.0) (6.3.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipykernel->jupyter->tsfm_public==0.2.0) (8.3.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipykernel->jupyter->tsfm_public==0.2.0) (5.3.1)
# Requirement already satisfied: nest-asyncio in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipykernel->jupyter->tsfm_public==0.2.0) (1.5.7)
# Requirement already satisfied: debugpy>=1.6.5 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipykernel->jupyter->tsfm_public==0.2.0) (1.6.7.post1)
# Requirement already satisfied: pyzmq>=20 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from ipykernel->jupyter->tsfm_public==0.2.0) (25.1.1)
# Requirement already satisfied: tinycss2 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from nbconvert->jupyter->tsfm_public==0.2.0) (1.2.1)
# Requirement already satisfied: jupyterlab-pygments in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from nbconvert->jupyter->tsfm_public==0.2.0) (0.2.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from nbconvert->jupyter->tsfm_public==0.2.0) (3.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from nbconvert->jupyter->tsfm_public==0.2.0) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from nbconvert->jupyter->tsfm_public==0.2.0) (4.12.2)
# Requirement already satisfied: nbformat>=5.7 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from nbconvert->jupyter->tsfm_public==0.2.0) (5.9.2)
# Requirement already satisfied: bleach!=5.0.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from nbconvert->jupyter->tsfm_public==0.2.0) (6.0.0)
# Requirement already satisfied: nbclient>=0.5.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from nbconvert->jupyter->tsfm_public==0.2.0) (0.8.0)
# Requirement already satisfied: defusedxml in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from nbconvert->jupyter->tsfm_public==0.2.0) (0.7.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from notebook->jupyter->tsfm_public==0.2.0) (2.12.5)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from notebook->jupyter->tsfm_public==0.2.0) (2.24.0)
# Requirement already satisfied: jupyterlab<4.2,>=4.1.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from notebook->jupyter->tsfm_public==0.2.0) (4.1.2)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from notebook->jupyter->tsfm_public==0.2.0) (0.2.3)
# Requirement already satisfied: qtpy>=2.4.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from qtconsole->jupyter->tsfm_public==0.2.0) (2.4.1)
# Requirement already satisfied: webencodings in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert->jupyter->tsfm_public==0.2.0) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.0) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->tsfm_public==0.2.0) (2.5.3)
# Requirement already satisfied: overrides in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (7.4.0)
# Requirement already satisfied: anyio>=3.1.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (3.7.1)
# Requirement already satisfied: terminado>=0.8.3 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (0.17.1)
# Requirement already satisfied: send2trash>=1.8.2 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (1.8.2)
# Requirement already satisfied: jupyter-server-terminals in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (0.4.4)
# Requirement already satisfied: prometheus-client in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (0.13.1)
# Requirement already satisfied: websocket-client in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (1.6.2)
# Requirement already satisfied: argon2-cffi in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (0.9.0)
# Requirement already satisfied: httpx>=0.25.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->tsfm_public==0.2.0) (0.25.2)
# Requirement already satisfied: async-lru>=1.0.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->tsfm_public==0.2.0) (2.0.4)
# Requirement already satisfied: tomli in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->tsfm_public==0.2.0) (2.0.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->tsfm_public==0.2.0) (2.2.0)
# Requirement already satisfied: jsonschema>=4.17.3 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->tsfm_public==0.2.0) (4.19.0)
# Requirement already satisfied: json5>=0.9.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->tsfm_public==0.2.0) (0.9.14)
# Requirement already satisfied: babel>=2.10 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->tsfm_public==0.2.0) (2.12.1)
# Requirement already satisfied: fastjsonschema in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter->tsfm_public==0.2.0) (2.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.0) (0.7.0)
# Requirement already satisfied: wcwidth in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.0) (0.2.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->tsfm_public==0.2.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->tsfm_public==0.2.0) (3.2.2)
# Requirement already satisfied: soupsieve>1.2 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter->tsfm_public==0.2.0) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.0) (1.2.0)
# Requirement already satisfied: pure-eval in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.0) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->tsfm_public==0.2.0) (2.2.1)
# Requirement already satisfied: mpmath>=0.19 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from sympy->torch!=1.12.0,>=1.11->transformers[torch]>=4.36.1->tsfm_public==0.2.0) (1.3.0)
# Requirement already satisfied: exceptiongroup in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (1.1.3)
# Requirement already satisfied: sniffio>=1.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (1.3.0)
# Requirement already satisfied: httpcore==1.* in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter->tsfm_public==0.2.0) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter->tsfm_public==0.2.0) (0.14.0)
# Requirement already satisfied: referencing>=0.28.4 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tsfm_public==0.2.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tsfm_public==0.2.0) (0.9.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tsfm_public==0.2.0) (2023.7.1)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (0.1.4)
# Requirement already satisfied: argon2-cffi-bindings in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (21.2.0)
# Requirement already satisfied: uri-template in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tsfm_public==0.2.0) (1.3.0)
# Requirement already satisfied: jsonpointer>1.13 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tsfm_public==0.2.0) (2.4)
# Requirement already satisfied: webcolors>=1.11 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tsfm_public==0.2.0) (1.13)
# Requirement already satisfied: fqdn in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tsfm_public==0.2.0) (1.5.1)
# Requirement already satisfied: isoduration in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tsfm_public==0.2.0) (20.11.0)
# Requirement already satisfied: cffi>=1.0.1 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (1.15.1)
# Requirement already satisfied: pycparser in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->tsfm_public==0.2.0) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/site-packages (from isoduration->jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tsfm_public==0.2.0) (1.2.3)
# Building wheels for collected packages: tsfm_public
#   Building wheel for tsfm_public (pyproject.toml) ... done
#   Created wheel for tsfm_public: filename=tsfm_public-0.2.0-py3-none-any.whl size=2303294 sha256=d38ce1f02c7de8ecd0875f3d93f30e81f3294f27b296ce89edc59ad65b9dc59b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l5e8dfaa/wheels/91/0b/a5/62aeda6aed2054a29fd91e1e24d2ff2edf6d9aded30338bdf4
# Successfully built tsfm_public
# Installing collected packages: tsfm_public
#   Attempting uninstall: tsfm_public
#     Found existing installation: tsfm_public 0.2.0
#     Uninstalling tsfm_public-0.2.0:
#       Successfully uninstalled tsfm_public-0.2.0
# Successfully installed tsfm_public-0.2.0

# %% [markdown]
# ## Imports

# %%
# Standard
import os
import math
import tempfile
import torch

# Third Party
from torch.optim import AdamW
from torch.optim.lr_scheduler import OneCycleLR
from transformers import EarlyStoppingCallback, Trainer, TrainingArguments, set_seed
import numpy as np
import pandas as pd

# First Party
from tsfm_public.models.tinytimemixer.utils import (
    count_parameters,
    plot_preds,
)

# Local
from tsfm_public.models.tinytimemixer import TinyTimeMixerForPrediction
from tsfm_public.toolkit.callbacks import TrackingCallback
# Out:
# 2024-06-10 11:33:09.085490: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Important arguments

# %%
# Set seed for reproducibility
SEED = 42
set_seed(SEED)

# DATA ROOT PATH
# Make sure to download the target data (here ettm2) on the `DATA_ROOT_PATH` folder.
# ETT is available at: https://github.com/zhouhaoyi/ETDataset/tree/main
target_dataset = "ettm2"
DATA_ROOT_PATH = "https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTm2.csv"

# Results dir
OUT_DIR = "ttm_finetuned_models/"

# TTM model branch
# Use main for 512-96 model
# Use "1024_96_v1" for 1024-96 model
TTM_MODEL_REVISION = "main"

# Forecasting parameters
context_length = 512
forecast_length = 96
fewshot_fraction = 0.05

# %% [markdown]
# ## Data processing pipeline

# %%
# Load the data file and see the columns
df_tmp = pd.read_csv(DATA_ROOT_PATH)
df_tmp
# Out:
#                       date       HUFL    HULL       MUFL    MULL    LUFL  \
# 0      2016-07-01 00:00:00  41.130001  12.481  36.535999   9.355   4.424
# 1      2016-07-01 00:15:00  39.622002  11.309  35.543999   8.551   3.209
# 2      2016-07-01 00:30:00  38.868000  10.555  34.365002   7.586   4.435
# 3      2016-07-01 00:45:00  35.518002   9.214  32.569000   8.712   4.435
# 4      2016-07-01 01:00:00  37.528000  10.136  33.936001   7.532   4.435
# ...                    ...        ...     ...        ...     ...     ...
# 69675  2018-06-26 18:45:00  42.722000  12.230  54.014000  12.652 -11.525
# 69676  2018-06-26 19:00:00  38.868000  10.052  49.859001  10.669 -11.525
# 69677  2018-06-26 19:15:00  39.622002  11.057  50.448002  11.795 -10.299
# 69678  2018-06-26 19:30:00  40.459999  11.392  51.841999  11.929 -11.536
# 69679  2018-06-26 19:45:00  43.223999  12.146  54.737000  12.679 -11.536
#
#         LULL         OT
# 0      1.311  38.661999
# 1      1.258  38.223000
# 2      1.258  37.344002
# 3      1.215  37.124001
# 4      1.215  37.124001
# ...      ...        ...
# 69675 -1.418  45.986500
# 69676 -1.418  45.986500
# 69677 -1.418  45.546501
# 69678 -1.418  45.546501
# 69679 -1.418  45.327000
#
# [69680 rows x 8 columns]

# %%
df_tmp.iloc[:1000].plot(x="date", y="HUFL", figsize=(20,5))
# Out:
# <Axes: xlabel='date'>

# %%
from tsfm_public.toolkit.time_series_preprocessor import TimeSeriesPreprocessor

dataset_path = DATA_ROOT_PATH
timestamp_column = "date"
id_columns = []
target_columns = ["HUFL", "HULL", "MUFL", "MULL", "LUFL", "LULL", "OT"]
split_config = {
                "train": [0, 12 * 30 * 24 * 4],
                "valid": [12 * 30 * 24 * 4, 12 * 30 * 24 * 4 + 4 * 30 * 24 * 4],
                "test": [
                    12 * 30 * 24 * 4 + 4 * 30 * 24 * 4,
                    12 * 30 * 24 * 4 + 8 * 30 * 24 * 4,
                ],
            }
# Understanding the split config -- slides

data = pd.read_csv(
    dataset_path,
    parse_dates=[timestamp_column],
)

column_specifiers = {
    "timestamp_column": timestamp_column,
    "id_columns": id_columns,
    "target_columns": target_columns,
    "control_columns": [],
}

tsp = TimeSeriesPreprocessor(
    **column_specifiers,
    context_length=context_length,
    prediction_length=forecast_length,
    scaling=True,
    encode_categorical=False,
    scaler_type="standard",
)

train_dataset, valid_dataset, test_dataset = tsp.get_datasets(
    data, split_config, fewshot_fraction=fewshot_fraction, fewshot_location="first"
)
print(f"Data lengths: train = {len(train_dataset)}, val = {len(valid_dataset)}, test = {len(test_dataset)}")
# Out:
# Data lengths: train = 1607, val = 11425, test = 11425
# /tmp/ipykernel_1538057/1603373431.py:38: DeprecationWarning: Call to deprecated method get_datasets. (Please use the standalone function `get_datasets()`.) -- Deprecated since version 0.1.1.
#   train_dataset, valid_dataset, test_dataset = tsp.get_datasets(

# %%
train_dataset[3]
# Out:
# {'past_values': tensor([[-0.5775, -0.6695, -0.8346,  ...,  0.6982,  0.4231,  0.8852],
#          [-0.3855, -0.4692, -0.7535,  ...,  0.6982,  0.4231,  0.8852],
#          [-0.3775, -0.4329, -0.7964,  ...,  0.5860,  0.4332,  0.8662],
#          ...,
#          [-0.4895, -0.3419, -0.8187,  ...,  0.3408,  0.2795,  0.4678],
#          [-0.4175,  0.2039, -0.6978,  ...,  0.3408,  0.4231,  0.4678],
#          [-0.3295,  0.3494, -0.6485,  ...,  0.3408,  0.2795,  0.5058]]),
#  'future_values': tensor([[ 0.0146,  0.6224, -0.4735,  0.8561,  0.3408,  0.2795,  0.5058],
#          [-0.1215,  0.5314, -0.4974,  0.7497,  0.3408,  0.2795,  0.4868],
#          [ 0.0787,  0.7317, -0.3686,  0.9801,  0.3408,  0.2795,  0.4868],
#          [ 0.1747,  0.7679, -0.3193,  1.0244,  0.3408,  0.2795,  0.4868],
#          [-0.3295,  0.0221, -0.6771, -0.0567,  0.3408,  0.2795,  0.4868],
#          [-0.5535, -0.2327, -0.8489, -0.4289,  0.3408,  0.2795,  0.5058],
#          [-0.5455, -0.3237, -0.8521, -0.6150,  0.3408,  0.2795,  0.5437],
#          [ 0.3107,  0.7317, -0.3193,  0.7497,  0.3408,  0.2795,  0.5437],
#          [-0.4336, -0.3419, -0.7789, -0.7036,  0.6204,  0.2795,  0.5437],
#          [-0.4656, -0.5420, -0.7948, -0.8719,  0.3339,  0.2795,  0.5627],
#          [-0.4015, -0.4875, -0.7392, -0.8276,  0.3339,  0.2795,  0.5816],
#          [-0.5696, -0.6512, -0.7837, -1.0405,  0.3339,  0.2795,  0.6006],
#          [-0.5455, -0.5057, -0.7582, -0.7479,  0.3339,  0.2795,  0.6196],
#          [-0.4735, -0.2872, -0.7344, -0.3846,  0.3339,  0.2795,  0.6576],
#          [-0.3135, -0.0872, -0.6374, -0.1277,  0.3339,  0.2795,  0.6955],
#          [-0.4175, -0.1417, -0.6835, -0.2871,  0.3339,  0.2795,  0.6955],
#          [-0.3935, -0.1599, -0.6692, -0.2606,  0.3339,  0.2795,  0.6955],
#          [-0.2255, -0.1964, -0.5929, -0.3582,  0.3339,  0.2795,  0.6955],
#          [-0.1694, -0.1234, -0.5451, -0.2249,  0.3339,  0.2795,  0.6955],
#          [-0.1054,  0.0038, -0.5340, -0.1363,  0.3339,  0.2795,  0.6955],
#          [-0.3375, -0.2692, -0.6835, -0.4468,  0.3339,  0.2795,  0.7335],
#          [-0.2815, -0.3419, -0.6549, -0.6415,  0.3339,  0.2795,  0.7335],
#          [-0.1535, -0.0689, -0.5976, -0.2696,  0.3339,  0.2795,  0.7714],
#          [ 0.0066,  0.0401, -0.5117, -0.1720,  0.3339,  0.2795,  0.7714],
#          [ 0.3427,  0.4404, -0.3113,  0.3156,  0.3339,  0.2795,  0.7904],
#          [ 0.1666,  0.3494, -0.3225,  0.3242,  0.3339,  0.2795,  0.8094],
#          [ 0.4948,  0.5679, -0.1746,  0.4928,  0.3339,  0.2795,  0.7714],
#          [ 0.4307,  0.4951, -0.2270,  0.4396,  0.3339,  0.2795,  0.6955],
#          [ 0.2306,  0.4224, -0.3447,  0.3510,  0.3339,  0.2795,  0.6386],
#          [ 0.4787,  0.6224, -0.2143,  0.5989,  0.3339,  0.2795,  0.6006],
#          [ 0.3107,  0.4586, -0.2938,  0.3953,  0.3339,  0.2795,  0.5817],
#          [ 0.2546,  0.2766, -0.3463,  0.1295,  0.3339,  0.2795,  0.5627],
#          [ 0.3908,  0.2949, -0.2557,  0.1648,  0.6318,  0.2795,  0.5627],
#          [ 0.4707,  0.3859, -0.1714,  0.3510,  0.2857,  0.2795,  0.5627],
#          [ 0.5427,  0.4041, -0.1793,  0.2624,  0.5585,  0.2795,  0.5627],
#          [ 0.3747,  0.2221, -0.2986,  0.0230,  0.5585,  0.2795,  0.5817],
#          [ 0.5188,  0.3676, -0.2000,  0.2002,  0.5585,  0.2795,  0.6006],
#          [ 0.6468,  0.4224, -0.1730,  0.1470,  0.5585,  0.4269,  0.6006],
#          [ 0.4548,  0.2586, -0.2032,  0.1648,  0.5585,  0.2795,  0.6006],
#          [ 0.4948,  0.3676, -0.2732,  0.0230,  0.8196,  0.4408,  0.6196],
#          [ 0.5347,  0.4404, -0.2239,  0.1559,  0.8196,  0.4408,  0.6196],
#          [ 0.1346, -0.3237, -0.4784, -0.8101,  0.5400,  0.4458,  0.6386],
#          [ 0.1507, -0.2144, -0.4370, -0.6593,  0.8471,  0.2795,  0.6386],
#          [ 0.0787, -0.1964, -0.4067, -0.4821,  0.2559,  0.2795,  0.6006],
#          [ 0.3107,  0.0038, -0.3399, -0.2782,  0.5654,  0.2795,  0.5627],
#          [ 0.5107,  0.1676, -0.2604, -0.2163,  0.5654,  0.4306,  0.5247],
#          [ 0.5747,  0.2949, -0.2302, -0.0391,  0.8495,  0.4420,  0.5058],
#          [ 0.5188,  0.3131, -0.2159,  0.0230,  0.8265,  0.4382,  0.5058],
#          [ 0.6228,  0.4404, -0.1984,  0.1205,  0.8265,  0.4382,  0.4678],
#          [ 0.4948,  0.4224, -0.1539,  0.3863,  0.3706,  0.2795,  0.4678],
#          [ 0.5347,  0.4404, -0.1602,  0.3242,  0.3706,  0.2795,  0.4868],
#          [ 0.3667,  0.2949, -0.3431,  0.0584,  0.6318,  0.4332,  0.5058],
#          [ 0.4787,  0.3314, -0.2747, -0.0477,  0.6318,  0.4282,  0.5058],
#          [ 0.2147,  0.1311, -0.4449, -0.2428,  0.6318,  0.4282,  0.5247],
#          [ 0.1906,  0.0583, -0.4640, -0.3668,  0.6318,  0.4282,  0.5247],
#          [ 0.1666, -0.0327, -0.4449, -0.4025,  0.6318,  0.2795,  0.5247],
#          [ 0.0946, -0.0872, -0.4306, -0.2960,  0.3087,  0.2795,  0.5247],
#          [ 0.2067,  0.1676, -0.4036, -0.0567,  0.5905,  0.2795,  0.5437],
#          [ 0.1266,  0.1311, -0.4226, -0.0656,  0.5905,  0.2795,  0.5437],
#          [ 0.1906,  0.1858, -0.4544, -0.1188,  0.5905,  0.4420,  0.5437],
#          [-0.0654,  0.0038, -0.6151, -0.3935,  0.5905,  0.4420,  0.5817],
#          [-0.1454, -0.0689, -0.5706, -0.2782,  0.5905,  0.2795,  0.5817],
#          [-0.0974, -0.0872, -0.4927, -0.1631,  0.3019,  0.2795,  0.5817],
#          [-0.1694, -0.2144, -0.5579, -0.3846,  0.3019,  0.2795,  0.5817],
#          [-0.0734, -0.0507, -0.5388, -0.2428,  0.5654,  0.2795,  0.5817],
#          [-0.0814, -0.0689, -0.5547, -0.3846,  0.5654,  0.2795,  0.5817],
#          [-0.3295, -0.2872, -0.6867, -0.6415,  0.5654,  0.2795,  0.5817],
#          [ 0.0226,  0.1311, -0.4751, -0.2074,  0.5654,  0.4257,  0.5817],
#          [-0.0895, -0.0144, -0.5451, -0.3225,  0.5654,  0.2795,  0.5817],
#          [-0.0334, -0.0144, -0.5117, -0.2074,  0.2331,  0.2795,  0.5817],
#          [-0.0814, -0.1054, -0.5674, -0.3757,  0.5333,  0.2795,  0.5817],
#          [-0.1215, -0.0507, -0.5499, -0.2339,  0.2651,  0.2795,  0.5627],
#          [-0.0974, -0.0507, -0.5547, -0.2782,  0.5286,  0.2795,  0.5248],
#          [-0.0174,  0.0401, -0.5261, -0.2249,  0.5286,  0.2795,  0.5248],
#          [-0.1614, -0.0327, -0.6215, -0.3314,  0.5286,  0.4332,  0.5248],
#          [-0.2815, -0.1599, -0.7153, -0.5618,  0.5286,  0.4306,  0.5248],
#          [-0.1614, -0.0872, -0.5722, -0.3225,  0.5286,  0.2795,  0.5248],
#          [-0.2334, -0.1417, -0.6135, -0.3403,  0.5286,  0.2795,  0.5248],
#          [-0.2654, -0.1599, -0.6262, -0.3314,  0.2675,  0.2795,  0.5248],
#          [-0.0814, -0.0327, -0.5149, -0.1720,  0.2675,  0.2795,  0.5248],
#          [-0.2495, -0.2509, -0.5483, -0.3225,  0.2675,  0.2795,  0.5248],
#          [-0.2334, -0.2509, -0.5738, -0.4468,  0.2675,  0.2795,  0.5248],
#          [-0.1054, -0.0872, -0.5277, -0.2249,  0.2675,  0.2795,  0.5248],
#          [-0.0814, -0.0872, -0.4513, -0.0920,  0.2675,  0.2795,  0.5248],
#          [ 0.0226,  0.1311, -0.4370,  0.0673,  0.2675,  0.2795,  0.5437],
#          [ 0.1186,  0.0948, -0.3749,  0.0052,  0.2675,  0.2795,  0.5437],
#          [-0.0014, -0.0327, -0.4274, -0.1453,  0.2675,  0.2795,  0.5437],
#          [-0.2014, -0.1599, -0.5897, -0.3582,  0.2675,  0.2795,  0.5437],
#          [ 0.0386,  0.0583, -0.4576, -0.1188,  0.2675,  0.2795,  0.5437],
#          [ 0.0706,  0.1129, -0.4354, -0.0391,  0.2675,  0.2795,  0.5437],
#          [-0.0334,  0.0948, -0.4274,  0.0762,  0.2675,  0.2795,  0.5437],
#          [-0.2654, -0.4147, -0.5992, -0.6329,  0.2675,  0.2795,  0.5437],
#          [-0.3775, -0.5785, -0.6755, -0.8012,  0.2675,  0.2795,  0.5627],
#          [-0.2895, -0.3237, -0.6072, -0.5086,  0.2675,  0.2795,  0.5817],
#          [-0.2495, -0.2327, -0.5738, -0.3757,  0.2675,  0.2795,  0.6196],
#          [ 0.0787,  0.2039, -0.3877,  0.2534,  0.2675,  0.2795,  0.6196]]),
#  'timestamp': numpy.datetime64('2016-07-06T08:30:00.000000000'),
#  'id': (0,)}

# %% [markdown]
# ## Zero-shot evaluation method

# %%
zeroshot_model = TinyTimeMixerForPrediction.from_pretrained("ibm-granite/granite-timeseries-ttm-v1", revision=TTM_MODEL_REVISION)
zeroshot_model
# Out:
# TinyTimeMixerForPrediction(
#   (backbone): TinyTimeMixerModel(
#     (encoder): TinyTimeMixerEncoder(
#       (patcher): Linear(in_features=64, out_features=192, bias=True)
#       (mlp_mixer_encoder): TinyTimeMixerBlock(
#         (mixers): ModuleList(
#           (0): TinyTimeMixerAdaptivePatchingBlock(
#             (mixer_layers): ModuleList(
#               (0-1): 2 x TinyTimeMixerLayer(
#                 (patch_mixer): PatchMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=32, out_features=64, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=64, out_features=32, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=32, out_features=32, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#                 (feature_mixer): FeatureMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=48, out_features=96, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=96, out_features=48, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=48, out_features=48, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#               )
#             )
#           )
#           (1): TinyTimeMixerAdaptivePatchingBlock(
#             (mixer_layers): ModuleList(
#               (0-1): 2 x TinyTimeMixerLayer(
#                 (patch_mixer): PatchMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=16, out_features=32, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=32, out_features=16, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=16, out_features=16, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#                 (feature_mixer): FeatureMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=96, out_features=192, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=192, out_features=96, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=96, out_features=96, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#               )
#             )
#           )
#           (2): TinyTimeMixerAdaptivePatchingBlock(
#             (mixer_layers): ModuleList(
#               (0-1): 2 x TinyTimeMixerLayer(
#                 (patch_mixer): PatchMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=8, out_features=16, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=16, out_features=8, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=8, out_features=8, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#                 (feature_mixer): FeatureMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=192, out_features=384, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=384, out_features=192, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=192, out_features=192, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#     (patching): TinyTimeMixerPatchify()
#     (scaler): TinyTimeMixerStdScaler()
#   )
#   (decoder): TinyTimeMixerDecoder(
#     (adapter): Linear(in_features=192, out_features=128, bias=True)
#     (decoder_block): TinyTimeMixerBlock(
#       (mixers): ModuleList(
#         (0-1): 2 x TinyTimeMixerLayer(
#           (patch_mixer): PatchMixerBlock(
#             (norm): TinyTimeMixerNormLayer(
#               (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             )
#             (mlp): TinyTimeMixerMLP(
#               (fc1): Linear(in_features=8, out_features=16, bias=True)
#               (dropout1): Dropout(p=0.2, inplace=False)
#               (fc2): Linear(in_features=16, out_features=8, bias=True)
#               (dropout2): Dropout(p=0.2, inplace=False)
#             )
#             (gating_block): TinyTimeMixerGatedAttention(
#               (attn_layer): Linear(in_features=8, out_features=8, bias=True)
#               (attn_softmax): Softmax(dim=-1)
#             )
#           )
#           (feature_mixer): FeatureMixerBlock(
#             (norm): TinyTimeMixerNormLayer(
#               (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             )
#             (mlp): TinyTimeMixerMLP(
#               (fc1): Linear(in_features=128, out_features=256, bias=True)
#               (dropout1): Dropout(p=0.2, inplace=False)
#               (fc2): Linear(in_features=256, out_features=128, bias=True)
#               (dropout2): Dropout(p=0.2, inplace=False)
#             )
#             (gating_block): TinyTimeMixerGatedAttention(
#               (attn_layer): Linear(in_features=128, out_features=128, bias=True)
#               (attn_softmax): Softmax(dim=-1)
#             )
#           )
#         )
#       )
#     )
#   )
#   (head): TinyTimeMixerForPredictionHead(
#     (dropout_layer): Dropout(p=0.2, inplace=False)
#     (base_forecast_block): Linear(in_features=1024, out_features=96, bias=True)
#     (flatten): Flatten(start_dim=-2, end_dim=-1)
#   )
# )

# %%
temp_dir = tempfile.mkdtemp()
# zeroshot_trainer
zeroshot_trainer = Trainer(
    model=zeroshot_model,
    args=TrainingArguments(
        output_dir=temp_dir,
        per_device_eval_batch_size=64,
    )
)

# %%
zeroshot_trainer.evaluate(test_dataset)
# Out:
#     <div>
#
#       <progress value='179' max='179' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [179/179 00:01]
#     </div>
# {'eval_loss': 0.1860235333442688,
#  'eval_runtime': 1.7746,
#  'eval_samples_per_second': 6437.921,
#  'eval_steps_per_second': 100.865}

# %%
# plot
plot_preds(trainer=zeroshot_trainer, dset=test_dataset, plot_dir=os.path.join(OUT_DIR, "ettm2"), plot_prefix="test_zeroshot", channel=0)

# %% [markdown]
#  ## Few-shot finetune and evaluation method

# %% [markdown]
# ### Load model
# Optionally, we can change some parameters of the model, e.g., dropout of the head.

# %%
finetune_forecast_model = TinyTimeMixerForPrediction.from_pretrained("ibm-granite/granite-timeseries-ttm-v1", revision=TTM_MODEL_REVISION, head_dropout=0.7)
finetune_forecast_model
# Out:
# TinyTimeMixerForPrediction(
#   (backbone): TinyTimeMixerModel(
#     (encoder): TinyTimeMixerEncoder(
#       (patcher): Linear(in_features=64, out_features=192, bias=True)
#       (mlp_mixer_encoder): TinyTimeMixerBlock(
#         (mixers): ModuleList(
#           (0): TinyTimeMixerAdaptivePatchingBlock(
#             (mixer_layers): ModuleList(
#               (0-1): 2 x TinyTimeMixerLayer(
#                 (patch_mixer): PatchMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=32, out_features=64, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=64, out_features=32, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=32, out_features=32, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#                 (feature_mixer): FeatureMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=48, out_features=96, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=96, out_features=48, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=48, out_features=48, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#               )
#             )
#           )
#           (1): TinyTimeMixerAdaptivePatchingBlock(
#             (mixer_layers): ModuleList(
#               (0-1): 2 x TinyTimeMixerLayer(
#                 (patch_mixer): PatchMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=16, out_features=32, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=32, out_features=16, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=16, out_features=16, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#                 (feature_mixer): FeatureMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=96, out_features=192, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=192, out_features=96, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=96, out_features=96, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#               )
#             )
#           )
#           (2): TinyTimeMixerAdaptivePatchingBlock(
#             (mixer_layers): ModuleList(
#               (0-1): 2 x TinyTimeMixerLayer(
#                 (patch_mixer): PatchMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=8, out_features=16, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=16, out_features=8, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=8, out_features=8, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#                 (feature_mixer): FeatureMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=192, out_features=384, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=384, out_features=192, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=192, out_features=192, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#     (patching): TinyTimeMixerPatchify()
#     (scaler): TinyTimeMixerStdScaler()
#   )
#   (decoder): TinyTimeMixerDecoder(
#     (adapter): Linear(in_features=192, out_features=128, bias=True)
#     (decoder_block): TinyTimeMixerBlock(
#       (mixers): ModuleList(
#         (0-1): 2 x TinyTimeMixerLayer(
#           (patch_mixer): PatchMixerBlock(
#             (norm): TinyTimeMixerNormLayer(
#               (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             )
#             (mlp): TinyTimeMixerMLP(
#               (fc1): Linear(in_features=8, out_features=16, bias=True)
#               (dropout1): Dropout(p=0.7, inplace=False)
#               (fc2): Linear(in_features=16, out_features=8, bias=True)
#               (dropout2): Dropout(p=0.7, inplace=False)
#             )
#             (gating_block): TinyTimeMixerGatedAttention(
#               (attn_layer): Linear(in_features=8, out_features=8, bias=True)
#               (attn_softmax): Softmax(dim=-1)
#             )
#           )
#           (feature_mixer): FeatureMixerBlock(
#             (norm): TinyTimeMixerNormLayer(
#               (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             )
#             (mlp): TinyTimeMixerMLP(
#               (fc1): Linear(in_features=128, out_features=256, bias=True)
#               (dropout1): Dropout(p=0.7, inplace=False)
#               (fc2): Linear(in_features=256, out_features=128, bias=True)
#               (dropout2): Dropout(p=0.7, inplace=False)
#             )
#             (gating_block): TinyTimeMixerGatedAttention(
#               (attn_layer): Linear(in_features=128, out_features=128, bias=True)
#               (attn_softmax): Softmax(dim=-1)
#             )
#           )
#         )
#       )
#     )
#   )
#   (head): TinyTimeMixerForPredictionHead(
#     (dropout_layer): Dropout(p=0.7, inplace=False)
#     (base_forecast_block): Linear(in_features=1024, out_features=96, bias=True)
#     (flatten): Flatten(start_dim=-2, end_dim=-1)
#   )
# )

# %% [markdown]
# ### Frezze the TTM backbone

# %%
print(
        "Number of params before freezing backbone",
        count_parameters(finetune_forecast_model),
    )

# Freeze the backbone of the model
for param in finetune_forecast_model.backbone.parameters():
    param.requires_grad = False

# Count params
print(
    "Number of params after freezing the backbone",
    count_parameters(finetune_forecast_model),
)
# Out:
# Number of params before freezing backbone 805280
# Number of params after freezing the backbone 289696

# %% [markdown]
# ### Finetune few-shot 5%

# %%
# Important parameters
learning_rate = 0.001
num_epochs = 1 # Ideally, we need more epochs (try offline preferably in a gpu for faster computation)
batch_size = 64

# %%
print(f"Using learning rate = {learning_rate}")
finetune_forecast_args = TrainingArguments(
    output_dir=os.path.join(OUT_DIR, "output"),
    overwrite_output_dir=True,
    learning_rate=learning_rate,
    num_train_epochs=num_epochs,
    do_eval=True,
    evaluation_strategy="epoch",
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    dataloader_num_workers=8,
    report_to=None,
    save_strategy="epoch",
    logging_strategy="epoch",
    save_total_limit=1,
    logging_dir=os.path.join(OUT_DIR, "logs"),  # Make sure to specify a logging directory
    load_best_model_at_end=True,  # Load the best model when training ends
    metric_for_best_model="eval_loss",  # Metric to monitor for early stopping
    greater_is_better=False,  # For loss
)

# Create the early stopping callback
early_stopping_callback = EarlyStoppingCallback(
    early_stopping_patience=10,  # Number of epochs with no improvement after which to stop
    early_stopping_threshold=0.0,  # Minimum improvement required to consider as improvement
)
tracking_callback = TrackingCallback()

# Optimizer and scheduler
optimizer = AdamW(finetune_forecast_model.parameters(), lr=learning_rate)
scheduler = OneCycleLR(
    optimizer,
    learning_rate,
    epochs=num_epochs,
    steps_per_epoch=math.ceil(len(train_dataset) / (batch_size)),
)

finetune_forecast_trainer = Trainer(
    model=finetune_forecast_model,
    args=finetune_forecast_args,
    train_dataset=train_dataset,
    eval_dataset=valid_dataset,
    callbacks=[early_stopping_callback, tracking_callback],
    optimizers=(optimizer, scheduler),
)

# Fine tune
finetune_forecast_trainer.train()
# Out:
# Using learning rate = 0.001
# /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#     <div>
#
#       <progress value='26' max='26' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [26/26 00:04, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.279100</td>
#       <td>0.132347</td>
#     </tr>
#   </tbody>
# </table><p>
# /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Checkpoint destination directory ttm_finetuned_models/output/checkpoint-26 already exists and is non-empty.Saving will proceed but saved results may be invalid.
# [TrackingCallback] Mean Epoch Time = 1.326690435409546 seconds, Total Train Time = 5.850828647613525
# TrainOutput(global_step=26, training_loss=0.2790809411268968, metrics={'train_runtime': 2.719, 'train_samples_per_second': 591.017, 'train_steps_per_second': 9.562, 'total_flos': 27828002979840.0, 'train_loss': 0.2790809411268968, 'epoch': 1.0})

# %%
finetune_forecast_trainer.evaluate(test_dataset)
# Out:
# /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#     <div>
#
#       <progress value='179' max='179' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [179/179 00:01]
#     </div>
# /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# {'eval_loss': 0.17345218360424042,
#  'eval_runtime': 1.4092,
#  'eval_samples_per_second': 8107.246,
#  'eval_steps_per_second': 127.019,
#  'epoch': 1.0}

# %% [markdown]
# ## Hands-on Questions with answers

# %% [markdown]
# ### Q 15.	Zero-shot on etth1.
# In your notebook, modify the zero-shot code to try it on etth1 dataset. Etth1 is available on https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv. What is the evaluation error you get on etth1?
# Use the following train/val/test splits:
# ```
# split_config = {
#                 "train": [0, 12 * 30 * 24],
#                 "valid": [12 * 30 * 24, 12 * 30 * 24 + 4 * 30 * 24],
#                 "test": [
#                     12 * 30 * 24 + 4 * 30 * 24,
#                     12 * 30 * 24 + 8 * 30 * 24,
#                 ],
#             }
# ```

# %%
DATA_ROOT_PATH = "https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv"

# %%
from tsfm_public.toolkit.time_series_preprocessor import TimeSeriesPreprocessor

dataset_path = DATA_ROOT_PATH
timestamp_column = "date"
id_columns = []
target_columns = ["HUFL", "HULL", "MUFL", "MULL", "LUFL", "LULL", "OT"]
split_config = {
                "train": [0, 12 * 30 * 24],
                "valid": [12 * 30 * 24, 12 * 30 * 24 + 4 * 30 * 24],
                "test": [
                    12 * 30 * 24 + 4 * 30 * 24,
                    12 * 30 * 24 + 8 * 30 * 24,
                ],
            }
# Understanding the split config -- slides

data = pd.read_csv(
    dataset_path,
    parse_dates=[timestamp_column],
)

column_specifiers = {
    "timestamp_column": timestamp_column,
    "id_columns": id_columns,
    "target_columns": target_columns,
    "control_columns": [],
}

tsp = TimeSeriesPreprocessor(
    **column_specifiers,
    context_length=context_length,
    prediction_length=forecast_length,
    scaling=True,
    encode_categorical=False,
    scaler_type="standard",
)

train_dataset, valid_dataset, test_dataset = tsp.get_datasets(
    data, split_config, fewshot_fraction=fewshot_fraction, fewshot_location="first"
)
print(f"Data lengths: train = {len(train_dataset)}, val = {len(valid_dataset)}, test = {len(test_dataset)}")
# Out:
# Data lengths: train = 311, val = 2785, test = 2785
# /tmp/ipykernel_1538057/1976991908.py:38: DeprecationWarning: Call to deprecated method get_datasets. (Please use the standalone function `get_datasets()`.) -- Deprecated since version 0.1.1.
#   train_dataset, valid_dataset, test_dataset = tsp.get_datasets(

# %%
zeroshot_model = TinyTimeMixerForPrediction.from_pretrained("ibm-granite/granite-timeseries-ttm-v1", revision=TTM_MODEL_REVISION)
temp_dir = tempfile.mkdtemp()
# zeroshot_trainer
zeroshot_trainer = Trainer(
    model=zeroshot_model,
    args=TrainingArguments(
        output_dir=temp_dir,
        per_device_eval_batch_size=64,
    )
)
zeroshot_trainer.evaluate(test_dataset)
# Out:
#     <div>
#
#       <progress value='44' max='44' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [44/44 00:00]
#     </div>
# {'eval_loss': 0.36317431926727295,
#  'eval_runtime': 0.3929,
#  'eval_samples_per_second': 7087.483,
#  'eval_steps_per_second': 111.975}

# %% [markdown]
# ### Q 16.	Zero-shot on etth1 by truncating the length
# Let’s say your application needs to forecast 24 hours in the future. You can still use the 512-96 TTM model and set the `prediction_filter_length` argument during model loading. Try it on etth1, and note the evaluation error (on all channels)?

# %%
zeroshot_model = TinyTimeMixerForPrediction.from_pretrained("ibm-granite/granite-timeseries-ttm-v1", revision=TTM_MODEL_REVISION, prediction_filter_length=24)
temp_dir = tempfile.mkdtemp()
# zeroshot_trainer
zeroshot_trainer = Trainer(
    model=zeroshot_model,
    args=TrainingArguments(
        output_dir=temp_dir,
        per_device_eval_batch_size=64,
    )
)
zeroshot_trainer.evaluate(test_dataset)
# Out:
#     <div>
#
#       <progress value='44' max='44' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [44/44 00:00]
#     </div>
# {'eval_loss': 0.31531819701194763,
#  'eval_runtime': 0.3923,
#  'eval_samples_per_second': 7098.902,
#  'eval_steps_per_second': 112.155}

# %% [markdown]
# ### Q 17.	Few-shot on etth1
# Try few-shot 5% forecasting on etth1. Freeze the backbone and fine-tune for only 1 epoch. What is the evaluation error you get?

# %%
finetune_forecast_model = TinyTimeMixerForPrediction.from_pretrained("ibm-granite/granite-timeseries-ttm-v1", revision=TTM_MODEL_REVISION, head_dropout=0.7)
finetune_forecast_model
# Out:
# TinyTimeMixerForPrediction(
#   (backbone): TinyTimeMixerModel(
#     (encoder): TinyTimeMixerEncoder(
#       (patcher): Linear(in_features=64, out_features=192, bias=True)
#       (mlp_mixer_encoder): TinyTimeMixerBlock(
#         (mixers): ModuleList(
#           (0): TinyTimeMixerAdaptivePatchingBlock(
#             (mixer_layers): ModuleList(
#               (0-1): 2 x TinyTimeMixerLayer(
#                 (patch_mixer): PatchMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=32, out_features=64, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=64, out_features=32, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=32, out_features=32, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#                 (feature_mixer): FeatureMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=48, out_features=96, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=96, out_features=48, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=48, out_features=48, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#               )
#             )
#           )
#           (1): TinyTimeMixerAdaptivePatchingBlock(
#             (mixer_layers): ModuleList(
#               (0-1): 2 x TinyTimeMixerLayer(
#                 (patch_mixer): PatchMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=16, out_features=32, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=32, out_features=16, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=16, out_features=16, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#                 (feature_mixer): FeatureMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=96, out_features=192, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=192, out_features=96, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=96, out_features=96, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#               )
#             )
#           )
#           (2): TinyTimeMixerAdaptivePatchingBlock(
#             (mixer_layers): ModuleList(
#               (0-1): 2 x TinyTimeMixerLayer(
#                 (patch_mixer): PatchMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=8, out_features=16, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=16, out_features=8, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=8, out_features=8, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#                 (feature_mixer): FeatureMixerBlock(
#                   (norm): TinyTimeMixerNormLayer(
#                     (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                   )
#                   (mlp): TinyTimeMixerMLP(
#                     (fc1): Linear(in_features=192, out_features=384, bias=True)
#                     (dropout1): Dropout(p=0.2, inplace=False)
#                     (fc2): Linear(in_features=384, out_features=192, bias=True)
#                     (dropout2): Dropout(p=0.2, inplace=False)
#                   )
#                   (gating_block): TinyTimeMixerGatedAttention(
#                     (attn_layer): Linear(in_features=192, out_features=192, bias=True)
#                     (attn_softmax): Softmax(dim=-1)
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#     (patching): TinyTimeMixerPatchify()
#     (scaler): TinyTimeMixerStdScaler()
#   )
#   (decoder): TinyTimeMixerDecoder(
#     (adapter): Linear(in_features=192, out_features=128, bias=True)
#     (decoder_block): TinyTimeMixerBlock(
#       (mixers): ModuleList(
#         (0-1): 2 x TinyTimeMixerLayer(
#           (patch_mixer): PatchMixerBlock(
#             (norm): TinyTimeMixerNormLayer(
#               (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             )
#             (mlp): TinyTimeMixerMLP(
#               (fc1): Linear(in_features=8, out_features=16, bias=True)
#               (dropout1): Dropout(p=0.7, inplace=False)
#               (fc2): Linear(in_features=16, out_features=8, bias=True)
#               (dropout2): Dropout(p=0.7, inplace=False)
#             )
#             (gating_block): TinyTimeMixerGatedAttention(
#               (attn_layer): Linear(in_features=8, out_features=8, bias=True)
#               (attn_softmax): Softmax(dim=-1)
#             )
#           )
#           (feature_mixer): FeatureMixerBlock(
#             (norm): TinyTimeMixerNormLayer(
#               (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             )
#             (mlp): TinyTimeMixerMLP(
#               (fc1): Linear(in_features=128, out_features=256, bias=True)
#               (dropout1): Dropout(p=0.7, inplace=False)
#               (fc2): Linear(in_features=256, out_features=128, bias=True)
#               (dropout2): Dropout(p=0.7, inplace=False)
#             )
#             (gating_block): TinyTimeMixerGatedAttention(
#               (attn_layer): Linear(in_features=128, out_features=128, bias=True)
#               (attn_softmax): Softmax(dim=-1)
#             )
#           )
#         )
#       )
#     )
#   )
#   (head): TinyTimeMixerForPredictionHead(
#     (dropout_layer): Dropout(p=0.7, inplace=False)
#     (base_forecast_block): Linear(in_features=1024, out_features=96, bias=True)
#     (flatten): Flatten(start_dim=-2, end_dim=-1)
#   )
# )

# %%
print(
        "Number of params before freezing backbone",
        count_parameters(finetune_forecast_model),
    )

# Freeze the backbone of the model
for param in finetune_forecast_model.backbone.parameters():
    param.requires_grad = False

# Count params
print(
    "Number of params after freezing the backbone",
    count_parameters(finetune_forecast_model),
)
# Out:
# Number of params before freezing backbone 805280
# Number of params after freezing the backbone 289696

# %%
print(f"Using learning rate = {learning_rate}")
finetune_forecast_args = TrainingArguments(
    output_dir=os.path.join(OUT_DIR, "output"),
    overwrite_output_dir=True,
    learning_rate=learning_rate,
    num_train_epochs=num_epochs,
    do_eval=True,
    evaluation_strategy="epoch",
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    dataloader_num_workers=8,
    report_to=None,
    save_strategy="epoch",
    logging_strategy="epoch",
    save_total_limit=1,
    logging_dir=os.path.join(OUT_DIR, "logs"),  # Make sure to specify a logging directory
    load_best_model_at_end=True,  # Load the best model when training ends
    metric_for_best_model="eval_loss",  # Metric to monitor for early stopping
    greater_is_better=False,  # For loss
)

# Create the early stopping callback
early_stopping_callback = EarlyStoppingCallback(
    early_stopping_patience=10,  # Number of epochs with no improvement after which to stop
    early_stopping_threshold=0.0,  # Minimum improvement required to consider as improvement
)
tracking_callback = TrackingCallback()

# Optimizer and scheduler
optimizer = AdamW(finetune_forecast_model.parameters(), lr=learning_rate)
scheduler = OneCycleLR(
    optimizer,
    learning_rate,
    epochs=num_epochs,
    steps_per_epoch=math.ceil(len(train_dataset) / (batch_size)),
)

finetune_forecast_trainer = Trainer(
    model=finetune_forecast_model,
    args=finetune_forecast_args,
    train_dataset=train_dataset,
    eval_dataset=valid_dataset,
    callbacks=[early_stopping_callback, tracking_callback],
    optimizers=(optimizer, scheduler),
)

# Fine tune
finetune_forecast_trainer.train()
# Out:
# Using learning rate = 0.001
# /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:03, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.038300</td>
#       <td>0.657834</td>
#     </tr>
#   </tbody>
# </table><p>
# /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# [TrackingCallback] Mean Epoch Time = 0.4230842590332031 seconds, Total Train Time = 4.267287492752075
# TrainOutput(global_step=5, training_loss=1.0382591247558595, metrics={'train_runtime': 1.1504, 'train_samples_per_second': 270.338, 'train_steps_per_second': 4.346, 'total_flos': 5385506488320.0, 'train_loss': 1.0382591247558595, 'epoch': 1.0})

# %%
finetune_forecast_trainer.evaluate(test_dataset)
# Out:
# /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#     <div>
#
#       <progress value='44' max='44' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [44/44 00:00]
#     </div>
# /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# {'eval_loss': 0.3646317720413208,
#  'eval_runtime': 0.6046,
#  'eval_samples_per_second': 4605.999,
#  'eval_steps_per_second': 72.77,
#  'epoch': 1.0}

# %% [markdown]
# ### Q 18.	Few-shot on etth1 by changing loss function
# Try few-shot 5% forecasting on etth1 by changing the `loss` to `mae` (mean absolute error). Freeze the backbone and fine-tune for only 1 epoch. What is the evaluation error you get?

# %%
finetune_forecast_model = TinyTimeMixerForPrediction.from_pretrained("ibm-granite/granite-timeseries-ttm-v1", revision=TTM_MODEL_REVISION, head_dropout=0.7, loss="mae")

# %%
print(
        "Number of params before freezing backbone",
        count_parameters(finetune_forecast_model),
    )

# Freeze the backbone of the model
for param in finetune_forecast_model.backbone.parameters():
    param.requires_grad = False

# Count params
print(
    "Number of params after freezing the backbone",
    count_parameters(finetune_forecast_model),
)
# Out:
# Number of params before freezing backbone 805280
# Number of params after freezing the backbone 289696

# %%
print(f"Using learning rate = {learning_rate}")
finetune_forecast_args = TrainingArguments(
    output_dir=os.path.join(OUT_DIR, "output"),
    overwrite_output_dir=True,
    learning_rate=learning_rate,
    num_train_epochs=num_epochs,
    do_eval=True,
    evaluation_strategy="epoch",
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    dataloader_num_workers=8,
    report_to=None,
    save_strategy="epoch",
    logging_strategy="epoch",
    save_total_limit=1,
    logging_dir=os.path.join(OUT_DIR, "logs"),  # Make sure to specify a logging directory
    load_best_model_at_end=True,  # Load the best model when training ends
    metric_for_best_model="eval_loss",  # Metric to monitor for early stopping
    greater_is_better=False,  # For loss
)

# Create the early stopping callback
early_stopping_callback = EarlyStoppingCallback(
    early_stopping_patience=10,  # Number of epochs with no improvement after which to stop
    early_stopping_threshold=0.0,  # Minimum improvement required to consider as improvement
)
tracking_callback = TrackingCallback()

# Optimizer and scheduler
optimizer = AdamW(finetune_forecast_model.parameters(), lr=learning_rate)
scheduler = OneCycleLR(
    optimizer,
    learning_rate,
    epochs=num_epochs,
    steps_per_epoch=math.ceil(len(train_dataset) / (batch_size)),
)

finetune_forecast_trainer = Trainer(
    model=finetune_forecast_model,
    args=finetune_forecast_args,
    train_dataset=train_dataset,
    eval_dataset=valid_dataset,
    callbacks=[early_stopping_callback, tracking_callback],
    optimizers=(optimizer, scheduler),
)

# Fine tune
finetune_forecast_trainer.train()
# Out:
# Using learning rate = 0.001
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:03, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.737100</td>
#       <td>0.552214</td>
#     </tr>
#   </tbody>
# </table><p>
# Checkpoint destination directory ttm_finetuned_models/output/checkpoint-5 already exists and is non-empty.Saving will proceed but saved results may be invalid.
# [TrackingCallback] Mean Epoch Time = 0.46452856063842773 seconds, Total Train Time = 4.299150228500366
# TrainOutput(global_step=5, training_loss=0.737077283859253, metrics={'train_runtime': 1.1782, 'train_samples_per_second': 263.956, 'train_steps_per_second': 4.244, 'total_flos': 5385506488320.0, 'train_loss': 0.737077283859253, 'epoch': 1.0})

# %%
finetune_forecast_trainer.evaluate(test_dataset)
# Out:
# /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#     <div>
#
#       <progress value='44' max='44' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [44/44 00:00]
#     </div>
# /dccstor/dnn_forecasting/conda_envs/envs/fm/lib/python3.9/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# {'eval_loss': 0.39811840653419495,
#  'eval_runtime': 0.5892,
#  'eval_samples_per_second': 4726.668,
#  'eval_steps_per_second': 74.676,
#  'epoch': 1.0}

# %% [markdown]
# ### Q 19.	Zero-shot on channel 0 and 2 for etth1
# In your notebook, add `prediction_channel_indices=[0,2]` during model loading to forecast only 0th and 2nd channels. In this case, execute the following code and note the output shape.
# ```
# zeroshot_model = TinyTimeMixerForPrediction.from_pretrained("ibm-granite/granite-timeseries-ttm-v1", revision=TTM_MODEL_REVISION, prediction_channel_indices=[0,2])
# output = zeroshot_model.forward(test_dataset[0]['past_values'].unsqueeze(0), return_loss=False)
# output.prediction_outputs.shape
# ```

# %%
zeroshot_model = TinyTimeMixerForPrediction.from_pretrained("ibm-granite/granite-timeseries-ttm-v1", revision=TTM_MODEL_REVISION, prediction_channel_indices=[0,2])
output = zeroshot_model.forward(test_dataset[0]['past_values'].unsqueeze(0), return_loss=False)
output.prediction_outputs.shape
# Out:
# torch.Size([1, 96, 2])
